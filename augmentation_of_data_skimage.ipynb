# %% [markdown]
# <a href="https://colab.research.google.com/github/ayaehab/GP_task2/blob/main/augmentation_of_data_skimage.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tensorflow with GPU
#
# This notebook provides an introduction to computing on a [GPU](https://cloud.google.com/gpu) in Colab. In this notebook you will connect to a GPU, and then run some basic TensorFlow operations on both the CPU and a GPU, observing the speedup provided by using the GPU.

# %% [markdown]
# ## Enabling and testing the GPU
#
# First, you'll need to enable GPUs for the notebook:
#
# - Navigate to Edit→Notebook Settings
# - select GPU from the Hardware Accelerator drop-down
#
# Next, we'll confirm that we can connect to the GPU with tensorflow:

# %%
# %tensorflow_version 2.x
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# TensorFlow 2.x selected.
# Found GPU at: /device:GPU:0

# %% [markdown]
# ## Observe TensorFlow speedup on GPU relative to CPU
#
# This example constructs a typical convolutional neural network layer over a
# random image and manually places the resulting ops on either the CPU or the GPU
# to compare execution speed.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
im=io.imread("/content/drive/MyDrive/graduation_project_task/DFUC2021_train/images/301000.jpg")

rotated = rotate(im, angle=30, mode = 'wrap')
#plot the rotated image

io.imshow(im)

# %%
io.imshow(rotated)

# %%
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import skimage.io as io
from skimage.transform import rotate, AffineTransform, warp
from skimage.util import random_noise
from skimage.filters import gaussian
import matplotlib.pyplot as plt


directory=os.listdir('/content/drive/MyDrive/graduation_project_task/DFUC2021_train/images/')
for d in directory:
    file='/content/drive/MyDrive/graduation_project_task/DFUC2021_train/images/'+d
    file_s="/content/drive/MyDrive/aug_data/AUG_"+d
    im=io.imread(file)
    
    rotated = rotate(im, angle=30, mode = 'wrap')
    #plot the rotated image
    io.imsave(file_s,rotated)

# %%
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import skimage.io as io
from skimage.transform import rotate, AffineTransform, warp
from skimage.util import random_noise
from skimage.filters import gaussian
import matplotlib.pyplot as plt

directory=os.listdir('/content/drive/MyDrive/graduation_project_task/DFUC2021_train/images/')
for d in directory:
    file='/content/drive/MyDrive/graduation_project_task/DFUC2021_train/images/'+d
    file_s="/content/drive/MyDrive/aug_data/AUG_"+d
    im=io.imread(file)
    
     tform = AffineTransform(shear=0.2,translation=im.shape[0]//10) 
    #plot the rotated image
     io.imsave(file_s,rotated)
