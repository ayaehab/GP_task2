# %%
import pandas as pd
import os
from os import walk

# %%
mypath="/media/fatmaosama/New Volume/database/PartA_DFU_Dataset/Abnormal"
abnormal = []
for (dirpath, dirnames, filenames) in walk(mypath):
    abnormal.extend(filenames)
    break

# %%
abnormal
# Out:
# ['2.02_7.jpg',
#  '2.08_290.jpg',
#  '.DS_Store',
#  '2.01_100.jpg',
#  '2.01_102.jpg',
#  '2.01_103.jpg',
#  '2.01_104.jpg',
#  '2.01_105.jpg',
#  '2.01_106.jpg',
#  '2.01_107.jpg',
#  '2.01_108.jpg',
#  '2.01_110.jpg',
#  '2.01_111.jpg',
#  '2.01_112.jpg',
#  '2.01_113.jpg',
#  '2.01_115.jpg',
#  '2.01_117.jpg',
#  '2.01_118.jpg',
#  '2.01_119.jpg',
#  '2.01_121.jpg',
#  '2.01_123.jpg',
#  '2.01_124.jpg',
#  '2.01_126.jpg',
#  '2.01_127.jpg',
#  '2.01_129.jpg',
#  '2.01_130.jpg',
#  '2.01_132.jpg',
#  '2.01_134.jpg',
#  '2.01_139.jpg',
#  '2.01_140.jpg',
#  '2.01_142.jpg',
#  '2.01_143.jpg',
#  '2.01_145.jpg',
#  '2.01_148.jpg',
#  '2.01_149.jpg',
#  '2.01_153.jpg',
#  '2.01_159.jpg',
#  '2.01_16.jpg',
#  '2.01_161.jpg',
#  '2.01_163.jpg',
#  '2.01_164.jpg',
#  '2.01_168.jpg',
#  '2.01_17.jpg',
#  '2.01_170.jpg',
#  '2.01_174.jpg',
#  '2.01_176.jpg',
#  '2.01_177.jpg',
#  '2.01_178.jpg',
#  '2.01_179.jpg',
#  '2.01_180.jpg',
#  '2.01_181.jpg',
#  '2.01_183.jpg',
#  '2.01_184.jpg',
# ...

# %%
mypath="/media/fatmaosama/New Volume/database/PartA_DFU_Dataset/Normal"
normal = []
for (dirpath, dirnames, filenames) in walk(mypath):
    normal.extend(filenames)
    break

# %%
normal
# Out:
# ['16_IMG_0148.jpg',
#  '.DS_Store',
#  '1.0_1.jpg',
#  '1.0_10.jpg',
#  '1.0_101.jpg',
#  '1.0_102.jpg',
#  '1.0_103.jpg',
#  '1.0_104.jpg',
#  '1.0_105.jpg',
#  '1.0_106.jpg',
#  '1.0_107.jpg',
#  '1.0_108.jpg',
#  '1.0_109.jpg',
#  '1.0_110.jpg',
#  '1.0_111.jpg',
#  '1.0_113.jpg',
#  '1.0_114.jpg',
#  '1.0_115.jpg',
#  '1.0_116.jpg',
#  '1.0_117.jpg',
#  '1.0_119.jpg',
#  '1.0_12.jpg',
#  '1.0_121.jpg',
#  '1.0_122.jpg',
#  '1.0_123.jpg',
#  '1.0_124.jpg',
#  '1.0_125.jpg',
#  '1.0_126.jpg',
#  '1.0_128.jpg',
#  '1.0_129.jpg',
#  '1.0_130.jpg',
#  '1.0_131.jpg',
#  '1.0_133.jpg',
#  '1.0_134.jpg',
#  '1.0_136.jpg',
#  '1.0_137.jpg',
#  '1.0_138.jpg',
#  '1.0_139.jpg',
#  '1.0_140.jpg',
#  '1.0_142.jpg',
#  '1.0_143.jpg',
#  '1.0_144.jpg',
#  '1.0_145.jpg',
#  '1.0_146.jpg',
#  '1.0_147.jpg',
#  '1.0_148.jpg',
#  '1.0_149.jpg',
#  '1.0_15.jpg',
#  '1.0_150.jpg',
#  '1.0_151.jpg',
#  '1.0_152.jpg',
#  '1.0_153.jpg',
#  '1.0_154.jpg',
#  '1.0_155.jpg',
#  '1.0_156.jpg',
# ...

# %%
mypath="/media/fatmaosama/New Volume/database/PartB_DFU_Dataset/Infection/Aug-Negative"
INF_negative = []
for (dirpath, dirnames, filenames) in walk(mypath):
    INF_negative.extend(filenames)
    break

# %%
INF_negative
# Out:
# ['000501_10.jpg',
#  '000501_10_M.jpg',
#  '000501_20.jpg',
#  '000501_20_M.jpg',
#  '000502_10.jpg',
#  '000502_20.jpg',
#  '000502_30.jpg',
#  '000503_10.jpg',
#  '000503_10_M.jpg',
#  '000503_20.jpg',
#  '000503_30.jpg',
#  '000504_10.jpg',
#  '000504_10_M.jpg',
#  '000504_20.jpg',
#  '000504_30.jpg',
#  '000504_30_M.jpg',
#  '000506_10.jpg',
#  '000506_30.jpg',
#  '000507_10.jpg',
#  '000507_10_M.jpg',
#  '000507_20.jpg',
#  '000507_30.jpg',
#  '000507_30_M.jpg',
#  '000508_10.jpg',
#  '000508_20.jpg',
#  '000508_20_M.jpg',
#  '000508_30.jpg',
#  '000508_30_M.jpg',
#  '000510_10.jpg',
#  '000510_20.jpg',
#  '000510_20_M.jpg',
#  '000510_30.jpg',
#  '000510_30_M.jpg',
#  '000511_10.jpg',
#  '000511_30.jpg',
#  '000515_10.jpg',
#  '000515_20.jpg',
#  '000515_30.jpg',
#  '000515_30_M.jpg',
#  '000517_10.jpg',
#  '000517_20.jpg',
#  '000517_30.jpg',
#  '000517_30_M.jpg',
#  '000519_11.jpg',
#  '000519_11_M.jpg',
#  '000519_21.jpg',
#  '000519_21_M.jpg',
#  '000519_31.jpg',
# ...

# %%
mypath="/media/fatmaosama/New Volume/database/PartB_DFU_Dataset/Infection/Aug-Positive"
INF_positive = []
for (dirpath, dirnames, filenames) in walk(mypath):
    INF_positive.extend(filenames)
    break

# %%
INF_positive
# Out:
# ['000505_10.jpg',
#  '000505_12.jpg',
#  '000505_20.jpg',
#  '000505_22.jpg',
#  '000505_30.jpg',
#  '000505_32.jpg',
#  '000509_10.jpg',
#  '000509_20.jpg',
#  '000509_30.jpg',
#  '000512_10.jpg',
#  '000512_20.jpg',
#  '000512_30.jpg',
#  '000513_11.jpg',
#  '000513_21.jpg',
#  '000513_31.jpg',
#  '000514_10.jpg',
#  '000514_20.jpg',
#  '000516_10.jpg',
#  '000516_20.jpg',
#  '000516_30.jpg',
#  '000518_10.jpg',
#  '000518_20.jpg',
#  '000518_30.jpg',
#  '000523_10.jpg',
#  '000523_20.jpg',
#  '000523_30.jpg',
#  '000531_11.jpg',
#  '000531_21.jpg',
#  '000531_31.jpg',
#  '000532_10.jpg',
#  '000532_20.jpg',
#  '000532_30.jpg',
#  '000533_10.jpg',
#  '000533_20.jpg',
#  '000534_10.jpg',
#  '000534_20.jpg',
#  '000534_30.jpg',
#  '000535_11.jpg',
#  '000535_21.jpg',
#  '000535_31.jpg',
#  '000536_10.jpg',
#  '000536_20.jpg',
#  '000536_30.jpg',
#  '000538_10.jpg',
#  '000538_20.jpg',
#  '000538_30.jpg',
#  '000541_11.jpg',
#  '000541_21.jpg',
#  '000541_31.jpg',
#  '000543_10.jpg',
# ...

# %%
mypath="/media/fatmaosama/New Volume/database/PartB_DFU_Dataset/Ischaemia/Aug-Positive"
ISC_positive = []
for (dirpath, dirnames, filenames) in walk(mypath):
    ISC_positive.extend(filenames)
    break

# %%
ISC_positive
# Out:
# ['000505_10.jpg',
#  '000505_10_M.jpg',
#  '000505_10_R1.jpg',
#  '000505_10_R1_M.jpg',
#  '000505_10_R2.jpg',
#  '000505_10_R2_M.jpg',
#  '000505_10_R3.jpg',
#  '000505_12.jpg',
#  '000505_12_M.jpg',
#  '000505_12_R1.jpg',
#  '000505_12_R1_M.jpg',
#  '000505_12_R2.jpg',
#  '000505_12_R2_M.jpg',
#  '000505_12_R3.jpg',
#  '000505_20.jpg',
#  '000505_20_M.jpg',
#  '000505_20_R1.jpg',
#  '000505_20_R2.jpg',
#  '000505_20_R2_M.jpg',
#  '000505_20_R3.jpg',
#  '000505_22.jpg',
#  '000505_22_M.jpg',
#  '000505_22_R1.jpg',
#  '000505_22_R1_M.jpg',
#  '000505_22_R2.jpg',
#  '000505_22_R2_M.jpg',
#  '000505_22_R3.jpg',
#  '000505_30.jpg',
#  '000505_30_M.jpg',
#  '000505_30_R1.jpg',
#  '000505_30_R1_M.jpg',
#  '000505_30_R2.jpg',
#  '000505_30_R2_M.jpg',
#  '000505_32.jpg',
#  '000505_32_M.jpg',
#  '000505_32_R1.jpg',
#  '000505_32_R1_M.jpg',
#  '000505_32_R2.jpg',
#  '000505_32_R2_M.jpg',
#  '000505_32_R3.jpg',
#  '000514_10.jpg',
#  '000514_10_M.jpg',
#  '000514_10_R1.jpg',
# ...

# %%
mypath="/media/fatmaosama/New Volume/database/PartB_DFU_Dataset/Ischaemia/Aug-Negative"
ISC_negative = []
for (dirpath, dirnames, filenames) in walk(mypath):
    ISC_negative.extend(filenames)
    break

# %%
ISC_negative
# Out:
# ['000501_10.jpg',
#  '000501_20.jpg',
#  '000501_30.jpg',
#  '000502_10.jpg',
#  '000502_20.jpg',
#  '000502_20_M.jpg',
#  '000502_30.jpg',
#  '000503_10.jpg',
#  '000503_20.jpg',
#  '000503_20_M.jpg',
#  '000503_30.jpg',
#  '000504_10.jpg',
#  '000504_10_M.jpg',
#  '000504_20.jpg',
#  '000504_30.jpg',
#  '000506_10.jpg',
#  '000506_20.jpg',
#  '000507_10.jpg',
#  '000507_20.jpg',
#  '000507_30.jpg',
#  '000508_10.jpg',
#  '000508_10_M.jpg',
#  '000508_20.jpg',
#  '000508_30.jpg',
#  '000509_10.jpg',
#  '000509_20.jpg',
#  '000509_30.jpg',
#  '000510_10.jpg',
#  '000510_20.jpg',
#  '000510_30.jpg',
#  '000511_10.jpg',
#  '000511_20.jpg',
#  '000511_30.jpg',
#  '000512_10.jpg',
#  '000512_30.jpg',
#  '000513_11.jpg',
#  '000513_21.jpg',
#  '000513_31.jpg',
#  '000515_10.jpg',
#  '000515_20.jpg',
#  '000515_30.jpg',
#  '000516_10.jpg',
#  '000516_20.jpg',
#  '000516_30.jpg',
#  '000517_10.jpg',
#  '000517_20.jpg',
#  '000517_20_M.jpg',
#  '000517_30.jpg',
#  '000518_10.jpg',
# ...

# %%
df = pd.DataFrame(columns = ['Name', 'Abnormal', 'Infection','Ischemia'])
df
# Out:
# Empty DataFrame
# Columns: [Name, Abnormal, Infection, Ischemia]
# Index: []

# %%
for i in range(len(normal)):
    df = df.append({'Name' : normal[i], 'Abnormal' : 0}, 
                    ignore_index = True)
df
# Out:
#                 Name Abnormal Infection Ischemia
# 0    16_IMG_0148.jpg        0       NaN      NaN
# 1          .DS_Store        0       NaN      NaN
# 2          1.0_1.jpg        0       NaN      NaN
# 3         1.0_10.jpg        0       NaN      NaN
# 4        1.0_101.jpg        0       NaN      NaN
# ..               ...      ...       ...      ...
# 637  96_IMG_0301.jpg        0       NaN      NaN
# 638  97_IMG_0303.jpg        0       NaN      NaN
# 639  98_IMG_0304.jpg        0       NaN      NaN
# 640  99_IMG_0306.jpg        0       NaN      NaN
# 641   9_IMG_0132.jpg        0       NaN      NaN
#
# [642 rows x 4 columns]

# %%
for i in range(len(abnormal)):
    df = df.append({'Name' : abnormal[i], 'Abnormal' : 1},
                    ignore_index = True)
df
# Out:
#                  Name Abnormal Infection Ischemia
# 0     16_IMG_0148.jpg        0       NaN      NaN
# 1           .DS_Store        0       NaN      NaN
# 2           1.0_1.jpg        0       NaN      NaN
# 3          1.0_10.jpg        0       NaN      NaN
# 4         1.0_101.jpg        0       NaN      NaN
# ...               ...      ...       ...      ...
# 1676      3.11_92.jpg        1       NaN      NaN
# 1677       3.12_1.jpg        1       NaN      NaN
# 1678     3.12_115.jpg        1       NaN      NaN
# 1679      3.12_55.jpg        1       NaN      NaN
# 1680      3.12_71.jpg        1       NaN      NaN
#
# [1681 rows x 4 columns]

# %%
for i in range(len(INF_negative)):
    df = df.append({'Name' : INF_negative[i], 'Infection' : 0},
                    ignore_index = True)
df
# Out:
#                  Name Abnormal Infection Ischemia
# 0     16_IMG_0148.jpg        0       NaN      NaN
# 1           .DS_Store        0       NaN      NaN
# 2           1.0_1.jpg        0       NaN      NaN
# 3          1.0_10.jpg        0       NaN      NaN
# 4         1.0_101.jpg        0       NaN      NaN
# ...               ...      ...       ...      ...
# 4621    001989_31.jpg      NaN         0      NaN
# 4622    001992_10.jpg      NaN         0      NaN
# 4623    001992_20.jpg      NaN         0      NaN
# 4624  001992_20_M.jpg      NaN         0      NaN
# 4625    001992_30.jpg      NaN         0      NaN
#
# [4626 rows x 4 columns]

# %%
for i in range(len(INF_positive)):
    df = df.append({'Name' : INF_positive[i], 'Infection' : 1},
                    ignore_index = True)
df
# Out:
#                  Name Abnormal Infection Ischemia
# 0     16_IMG_0148.jpg        0       NaN      NaN
# 1           .DS_Store        0       NaN      NaN
# 2           1.0_1.jpg        0       NaN      NaN
# 3          1.0_10.jpg        0       NaN      NaN
# 4         1.0_101.jpg        0       NaN      NaN
# ...               ...      ...       ...      ...
# 7566    001994_11.jpg      NaN         1      NaN
# 7567    001994_20.jpg      NaN         1      NaN
# 7568    001994_21.jpg      NaN         1      NaN
# 7569    001994_30.jpg      NaN         1      NaN
# 7570    001994_31.jpg      NaN         1      NaN
#
# [7571 rows x 4 columns]

# %%
for i in range(len(ISC_negative)):
    df = df.append({'Name' : ISC_negative[i], 'Ischemia' : 0},
                    ignore_index = True)
df
# Out:
#                   Name Abnormal Infection Ischemia
# 0      16_IMG_0148.jpg        0       NaN      NaN
# 1            .DS_Store        0       NaN      NaN
# 2            1.0_1.jpg        0       NaN      NaN
# 3           1.0_10.jpg        0       NaN      NaN
# 4          1.0_101.jpg        0       NaN      NaN
# ...                ...      ...       ...      ...
# 12501    001994_20.jpg      NaN       NaN        0
# 12502    001994_21.jpg      NaN       NaN        0
# 12503    001994_30.jpg      NaN       NaN        0
# 12504    001994_31.jpg      NaN       NaN        0
# 12505  001994_31_M.jpg      NaN       NaN        0
#
# [12506 rows x 4 columns]

# %%
for i in range(len(ISC_positive)):
    df = df.append({'Name' : ISC_positive[i], 'Ischemia' : 1},
                    ignore_index = True)
df
# Out:
#                      Name Abnormal Infection Ischemia
# 0         16_IMG_0148.jpg        0       NaN      NaN
# 1               .DS_Store        0       NaN      NaN
# 2               1.0_1.jpg        0       NaN      NaN
# 3              1.0_10.jpg        0       NaN      NaN
# 4             1.0_101.jpg        0       NaN      NaN
# ...                   ...      ...       ...      ...
# 17436    001988_30_R1.jpg      NaN       NaN        1
# 17437  001988_30_R1_M.jpg      NaN       NaN        1
# 17438    001988_30_R2.jpg      NaN       NaN        1
# 17439  001988_30_R2_M.jpg      NaN       NaN        1
# 17440    001988_30_R3.jpg      NaN       NaN        1
#
# [17441 rows x 4 columns]

# %%
df = df.replace(np.nan, 0)
df
# Out:
#                      Name  Abnormal  Infection  Ischemia
# 0         16_IMG_0148.jpg         0          0         0
# 1               .DS_Store         0          0         0
# 2               1.0_1.jpg         0          0         0
# 3              1.0_10.jpg         0          0         0
# 4             1.0_101.jpg         0          0         0
# ...                   ...       ...        ...       ...
# 17436    001988_30_R1.jpg         0          0         1
# 17437  001988_30_R1_M.jpg         0          0         1
# 17438    001988_30_R2.jpg         0          0         1
# 17439  001988_30_R2_M.jpg         0          0         1
# 17440    001988_30_R3.jpg         0          0         1
#
# [17441 rows x 4 columns]

# %%
df.to_csv("new_csvsheet.csv",index=False)

# %%
df["Abnormal"].value_counts()
# Out:
# 0    16402
# 1     1039
# Name: Abnormal, dtype: int64

# %%
df["Infection"].value_counts()
# Out:
# 0    14496
# 1     2945
# Name: Infection, dtype: int64

# %%
df["Ischemia"].value_counts()
# Out:
# 0    12506
# 1     4935
# Name: Ischemia, dtype: int64

# %%
df.groupby('Name').count()
# Out:
#                  Abnormal  Infection  Ischemia
# Name
# .DS_Store               2          2         2
# 000501_10.jpg           2          2         2
# 000501_10_M.jpg         1          1         1
# 000501_20.jpg           2          2         2
# 000501_20_M.jpg         1          1         1
# ...                   ...        ...       ...
# 96_IMG_0301.jpg         1          1         1
# 97_IMG_0303.jpg         1          1         1
# 98_IMG_0304.jpg         1          1         1
# 99_IMG_0306.jpg         1          1         1
# 9_IMG_0132.jpg          1          1         1
#
# [12277 rows x 3 columns]

# %%
df=pd.read_csv("new_csvsheet.csv")
df
# Out:
#                      Name  Abnormal  Infection  Ischemia
# 0         16_IMG_0148.jpg         0          0         0
# 1               1.0_1.jpg         0          0         0
# 2              1.0_10.jpg         0          0         0
# 3             1.0_101.jpg         0          0         0
# 4             1.0_102.jpg         0          0         0
# ...                   ...       ...        ...       ...
# 17434    001988_30_R1.jpg         0          0         1
# 17435  001988_30_R1_M.jpg         0          0         1
# 17436    001988_30_R2.jpg         0          0         1
# 17437  001988_30_R2_M.jpg         0          0         1
# 17438    001988_30_R3.jpg         0          0         1
#
# [17439 rows x 4 columns]

# %%
df.groupby('Name').count()
# Out:
#                  Abnormal  Infection  Ischemia
# Name
# 000501_10.jpg           2          2         2
# 000501_10_M.jpg         1          1         1
# 000501_20.jpg           2          2         2
# 000501_20_M.jpg         1          1         1
# 000501_30.jpg           1          1         1
# ...                   ...        ...       ...
# 96_IMG_0301.jpg         1          1         1
# 97_IMG_0303.jpg         1          1         1
# 98_IMG_0304.jpg         1          1         1
# 99_IMG_0306.jpg         1          1         1
# 9_IMG_0132.jpg          1          1         1
#
# [12276 rows x 3 columns]

# %%
aggregation_functions = {'Name': 'first', 'Abnormal': 'sum', 'Infection': 'sum','Ischemia':'sum'}
df_new = df.groupby(df['Name']).aggregate(aggregation_functions)

# %%
df_new.reset_index(drop=True, inplace=True) 
df_new
# Out:
#                   Name  Abnormal  Infection  Ischemia
# 0        000501_10.jpg         0          0         0
# 1      000501_10_M.jpg         0          0         0
# 2        000501_20.jpg         0          0         0
# 3      000501_20_M.jpg         0          0         0
# 4        000501_30.jpg         0          0         0
# ...                ...       ...        ...       ...
# 12271  96_IMG_0301.jpg         0          0         0
# 12272  97_IMG_0303.jpg         0          0         0
# 12273  98_IMG_0304.jpg         0          0         0
# 12274  99_IMG_0306.jpg         0          0         0
# 12275   9_IMG_0132.jpg         0          0         0
#
# [12276 rows x 4 columns]

# %%
df_new.groupby('Name').count()
# Out:
#                  Abnormal  Infection  Ischemia
# Name
# 000501_10.jpg           1          1         1
# 000501_10_M.jpg         1          1         1
# 000501_20.jpg           1          1         1
# 000501_20_M.jpg         1          1         1
# 000501_30.jpg           1          1         1
# ...                   ...        ...       ...
# 96_IMG_0301.jpg         1          1         1
# 97_IMG_0303.jpg         1          1         1
# 98_IMG_0304.jpg         1          1         1
# 99_IMG_0306.jpg         1          1         1
# 9_IMG_0132.jpg          1          1         1
#
# [12276 rows x 3 columns]

# %%
df_new.to_csv("new_csvsheet.csv",index=False)

# %%
df=pd.read_csv("new_csvsheet.csv")
df.groupby('Name').count()
# Out:
#                  Abnormal  Infection  Ischemia
# Name
# 000501_10.jpg           1          1         1
# 000501_10_M.jpg         1          1         1
# 000501_20.jpg           1          1         1
# 000501_20_M.jpg         1          1         1
# 000501_30.jpg           1          1         1
# ...                   ...        ...       ...
# 96_IMG_0301.jpg         1          1         1
# 97_IMG_0303.jpg         1          1         1
# 98_IMG_0304.jpg         1          1         1
# 99_IMG_0306.jpg         1          1         1
# 9_IMG_0132.jpg          1          1         1
#
# [12276 rows x 3 columns]
